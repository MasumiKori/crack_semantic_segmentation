# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/My\ Drive/Colab Notebooks/

# %%
from image_segmentation_keras.keras_segmentation.models.unet import vgg_unet

model = vgg_unet(n_classes=256 ,  input_height=256, input_width=256)

model.train(
    train_images =  "./split/images_prepped_train/",
    train_annotations = "./split/annotations_prepped_train/",
    checkpoints_path = "/content/gdrive/My Drive/Colab Notebooks/checkpoints/vgg_unet_720_epoch20" , epochs=20
)

out = model.predict_segmentation(
    inp="split/images_prepped_test/crack7_4.png",
    out_fname="./content/gdrive/My Drive/Colab Notebooks/data/crack7_4.png"
)

import matplotlib.pyplot as plt
plt.imshow(out)

# evaluating the model 
#print(model.evaluate_segmentation( inp_images_dir="dataset1/images_prepped_test/"  , annotations_dir="dataset1/annotations_prepped_test/" ) )

# %%
out = model.predict_segmentation(
    inp="split/images_prepped_test/crack7_44.png",
    out_fname="/tmp/out.png"
)

import matplotlib.pyplot as plt
plt.imshow(out)

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# evaluating the model 
#print(model.evaluate_segmentation( inp_images_dir="dataset1/images_prepped_test/"  , annotations_dir="dataset1/annotations_prepped_test/" ) )
